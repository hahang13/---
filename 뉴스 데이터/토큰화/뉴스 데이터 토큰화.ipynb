# %%
import csv
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
from nltk.tokenize import word_tokenize
from collections import Counter
from nltk.corpus import stopwords

nltk.download('vader_lexicon')
nltk.download('stopwords')

stopwords = '``','…'
stop_iist = stopwords.split(',')

# CSV 파일 열기
with open('../뉴스 크롤링/관련주 크롤링/하이닉스1.csv', 'r', encoding='utf-8') as file:
    reader = csv.reader(file)
    
    # 헤더 읽기
    header = next(reader)
    
    # 텍스트 데이터 열 인덱스 지정
    text_column_index = 1  # 예시로 두 번째 열을 텍스트 데이터로 가정
    
    # 텍스트 데이터 토큰화 및 감정 분석
    tokens = []
    for row in reader:
        text = row[text_column_index]
        text_tokens = word_tokenize(text)  # 단어 토큰화
        tokens.extend(text_tokens)
        
    # 토큰화된 단어들의 빈도수 계산
    word_freq = Counter(tokens)
    
    # 감정 분석 수행
    sia = SentimentIntensityAnalyzer()
    sentiment_scores = {}
    for word, freq in word_freq.items():
        sentiment_score = sia.polarity_scores(word)['compound']
        sentiment_scores[word] = sentiment_score * freq
        
# 감정 분석 결과 출력
for word, score in sentiment_scores.items():
    print(f"{word}: {score}")
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 12
#       9 nltk.download('stopwords')
#      11 stopwords = '``','…'
# ---> 12 stop_iist = stopwords.split(',')
#      14 # CSV 파일 열기
#      15 with open('../뉴스 크롤링/관련주 크롤링/하이닉스1.csv', 'r', encoding='utf-8') as file:
#
# AttributeError: 'tuple' object has no attribute 'split'

# %%
f = open("../뉴스 크롤링/하이닉스.csv",'rt',encoding='utf-8')
lines = f.readlines()
line = []
for i in range(len(lines)):
    line.append(lines[i])
f.close()

print(line)
##영어 텍스트##
# f = open("./stevejobs.txt",'rt',encoding='utf-8')
# lines2 = f.readlines()
# line2 = []
# for i in range(len(lines2)):
    # line2.append(lines2[i])
# f.close()

print(line2)
# Out:
# ['\ufeffdate,title,link,content\n', 'None,None,https://sports.news.naver.com/news.nhn?oid=001&aid=0014019444,[]\n', 'None,None,https://sports.news.naver.com/news.nhn?oid=003&aid=0011930358,[]\n', 'None,None,https://sports.news.naver.com/news.nhn?oid=001&aid=0013948193,[]\n', '2023-06-25 17:21:05,외국인 짐싸나…4~5월 6조 담더니 최근 한주에 1조어치 팔았다,https://n.news.naver.com/mnews/article/009/0005149069?sid=101,"[\n', '\n', '\n', '\n', '\n', ' 사진은 기사 내용과 직접적인 관련이 없음. [출처 : 연합뉴스]지난 4~5월 국내증시에서 강한 매수세를 보이며 지수를 끌어올렸던 외국인들이 이달 들어 순매도로 전환한 것으로 나타났다. 외국인의 순매도 전환에 지수도 주춤한 모습이다.증권가에서는 외국인 투자자들이 잠시 쉬어가는 모습을 보이고 있지만 순매수 추세가 반전된 것은 아니라는 분석을 내놓고 있다.23일 증권가에 따르면 6월 들어 이날까지 외국인 투자자들은 코스피 시장에서 4625억원, 코스닥 시장에서 3162억원을 순매도했다.특히 최근 들어 매도세가 거세다. 지난 19일 3604억원, 20일 2812억원, 21일 1999억원, 전날 1068억원에 이어 이날 1872억원까지 이번 한주 동안에만 코스피 시장에서 1조1356억원을 순매도했다.지난 4~5월까지만 해도 외국인은 국내 증시의 상승세를 견인했다. 외국인 투자자는 지난 4월 한달 동안 코스피 시